# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("adult_data.csv")
data2 = pd.read_csv("adult_test.csv")
final = pd.concat([data, data2])
# salary = data["salary"]
# sex = data["sex"]
# sns.countplot(salary, hue=sex)
occupation = data["occupation"]
hours = data["hours-per-week"]

sns.boxplot(occupation, hours, showmeans=True, meanprops={"marker":"+",
                       "markerfacecolor":"white", 
                       "markeredgecolor":"black",
                      "markersize":"100"})
# Out:
# C:\Users\barnw\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='occupation', ylabel='hours-per-week'>
